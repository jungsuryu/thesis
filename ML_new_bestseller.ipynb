# %%
# 필요한 모듈 불러오기

import os
import numpy as np
import pandas as pd

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action = 'ignore')

import pickle

# %%
# 실험 준비

## 데이터 불러오기
ratings_cols = ['user_id', 'item_id', 'rating', 'timestamp']
movie_cols = ['item_id', 'title', 'genre']
user_cols = ['user_id', 'sex', 'age', 'occupation', 'zip_code']

ratings = pd.read_csv('/home/ryu/thesis/data/ml-1m/ratings.dat', sep='::', names=ratings_cols, engine='python', encoding = "ISO-8859-1")
movies = pd.read_csv('/home/ryu/thesis/data/ml-1m/movies.dat', sep='::', names=movie_cols, engine='python', encoding = "ISO-8859-1")
users = pd.read_csv('/home/ryu/thesis/data/ml-1m/users.dat', sep='::', names=user_cols, engine='python', encoding = "ISO-8859-1")

## 평점 없는 영화 제거
movies_in_rating = ratings['item_id'].unique()
movies = movies[movies['item_id'].isin(movies_in_rating)]

## 장르 정리
genres_df = movies['genre'].str.get_dummies(sep='|')
movies = pd.concat([movies, genres_df], axis=1)
# movies = movies.drop(['genre'], axis=1)

## 필요한 정보만 추출
users = users[['user_id', 'age', 'sex', 'occupation']]

# 데이터 합병
data = pd.merge(ratings, movies, how='inner', on='item_id')
data = pd.merge(data, users, how='inner', on='user_id')
data['age'] /= 50

x = data.copy()
y = data['user_id']
ratings_train, ratings_test = train_test_split(x, test_size=0.25, stratify=y, random_state=84)


# White Sheep 대상 MF 실험 결과 불러오기 (NeuMF 실험 시 사용)
with open('/home/ryu/thesis/real_movielens/additional_var/White_FM/84p_White FM.pkl', 'rb') as f:
    white_results_loaded = pickle.load(f)

## Open saved user_gsu_dict (Gray Sheep id 불러오기)
with open('/home/ryu/thesis/real_movielens/additional_var/1_gsu_data/FM_84_pearson_gsu.pkl', 'rb') as f:
    gray_dict = pickle.load(f)

# %%
# RMSE 준비
def RMSE(y_true, y_pred):
    return np.sqrt(np.mean((np.array(y_true) - np.array(y_pred))**2))


# 모델 준비
def Biased_Bestseller(train_data, test_data):

    train = train_data.copy()
    test = test_data.copy()

    # 아이템별 평균 평점 계산
    rating_mean = train.groupby('item_id')['rating'].mean()
    test = test.join(rating_mean, on='item_id', rsuffix='_item')

    # 전체 평균 평점 계산
    global_mean = train['rating'].mean()
    test['rating_item'].fillna(train['rating'].mean(), inplace=True)

    # 사용자별 평균 평점
    user_mean = train.groupby('user_id')['rating'].mean()
    test = test.join(user_mean, on='user_id', rsuffix='_user')
    
    
    test['predicted_rating'] = test['rating_item'] - global_mean + test['rating_user']

    rmse_result = RMSE(test['rating'], test['predicted_rating'])

    return rmse_result

# %%
bias_bestseller = {}
weighted_bias_bs = {}
gray_bias_bestseller = {}
weighted_gray_bias_bs = {}

for thresh in gray_dict.keys():

    
    gray_idx = gray_dict[thresh]    # thresh%에 해당하는 Gray sheep 사용자 id 가져오기
    white_rmse = white_results_loaded[thresh]    # thresh%에 해당하는 White Sheep MF 결과 가져오기 (NeuMF 실험 시에만 사용!)

    print('**************************************************')
    print(f'                {thresh}% 실험 시작                ')
    print('**************************************************')


    # white, gray sheep 사용자 분리
    white = ratings[~ratings['user_id'].isin(gray_idx)]
    gray = ratings[ratings['user_id'].isin(gray_idx)]

    white_train = ratings_train[~ratings_train['user_id'].isin(gray_idx)]
    white_test = ratings_test[~ratings_test['user_id'].isin(gray_idx)]

    gray_train = ratings_train[ratings_train['user_id'].isin(gray_idx)]
    gray_test = ratings_test[ratings_test['user_id'].isin(gray_idx)]

    #### 2. Bestseller with all ratings ####
    bias_bestseller_rmse = Biased_Bestseller(ratings_train, gray_test)
    

    print(f'{thresh}% Bestseller RMSE: {bias_bestseller_rmse}')
    bias_bestseller[f'{thresh}'] = bias_bestseller_rmse

    weight_bias_avg_bs = (white_rmse * (1 - (int(thresh)*0.01))) + (bias_bestseller_rmse * (int(thresh)*0.01))
    print(f'{thresh}% Bestseller weighted RMSE: {weight_bias_avg_bs}')
    weighted_bias_bs[f'{thresh}'] = weight_bias_avg_bs

    #### 3. Gray Sheep Only Bestseller ####
    gsu_bias_bestseller_rmse = Biased_Bestseller(gray_train, gray_test)

    print(f'{thresh}% GSU Bestseller RMSE: {gsu_bias_bestseller_rmse}')
    gray_bias_bestseller[f'{thresh}'] = gsu_bias_bestseller_rmse

    weight_avg_bias_gray_bs = (white_rmse * (1 - (int(thresh)*0.01))) + (gsu_bias_bestseller_rmse * (int(thresh)*0.01))
    print(f'{thresh}% GSU Bestseller weighted RMSE: {weight_avg_bias_gray_bs}')
    weighted_gray_bias_bs[f'{thresh}'] = weight_avg_bias_gray_bs
# Out:
# **************************************************
#                 1% 실험 시작
# **************************************************
# 1% Bestseller RMSE: 0.8786363648802383
# 1% Bestseller weighted RMSE: 0.8902193174907082
# 1% GSU Bestseller RMSE: 0.9589236782503325
# 1% GSU Bestseller weighted RMSE: 0.8910221906244091
# **************************************************
#                 2% 실험 시작
# **************************************************
# 2% Bestseller RMSE: 0.9100549079802958
# 2% Bestseller weighted RMSE: 0.8900467746330004
# 2% GSU Bestseller RMSE: 0.9611219672401173
# 2% GSU Bestseller weighted RMSE: 0.8910681158181969
# **************************************************
#                 3% 실험 시작
# **************************************************
# 3% Bestseller RMSE: 0.9136236919239346
# 3% Bestseller weighted RMSE: 0.8907433897292104
# 3% GSU Bestseller RMSE: 0.9554733964883383
# 3% GSU Bestseller weighted RMSE: 0.8919988808661425
# **************************************************
#                 4% 실험 시작
# **************************************************
# 4% Bestseller RMSE: 0.9102689399066588
# 4% Bestseller weighted RMSE: 0.8898041150555187
# 4% GSU Bestseller RMSE: 0.9431155390392071
# 4% GSU Bestseller weighted RMSE: 0.8911179790208207
# **************************************************
#                 5% 실험 시작
# **************************************************
# 5% Bestseller RMSE: 0.9105184820527366
# 5% Bestseller weighted RMSE: 0.8900751733372466
# 5% GSU Bestseller RMSE: 0.9371402473368745
# 5% GSU Bestseller weighted RMSE: 0.8914062616014535
# **************************************************
#                 6% 실험 시작
# **************************************************
# 6% Bestseller RMSE: 0.9064070192189649
# 6% Bestseller weighted RMSE: 0.8910525944770152
# 6% GSU Bestseller RMSE: 0.9286225290741698
# 6% GSU Bestseller weighted RMSE: 0.8923855250683275
# **************************************************
#                 7% 실험 시작
# **************************************************
# 7% Bestseller RMSE: 0.9038462206220016
# 7% Bestseller weighted RMSE: 0.890929752477348
# 7% GSU Bestseller RMSE: 0.9249637181361462
# 7% GSU Bestseller weighted RMSE: 0.8924079773033381
# **************************************************
#                 8% 실험 시작
# **************************************************
# 8% Bestseller RMSE: 0.9062966884118469
# 8% Bestseller weighted RMSE: 0.8921004253047177
# 8% GSU Bestseller RMSE: 0.924751538663462
# 8% GSU Bestseller weighted RMSE: 0.893576813324847
# **************************************************
#                 9% 실험 시작
# **************************************************
# 9% Bestseller RMSE: 0.9034976326264055
# 9% Bestseller weighted RMSE: 0.8922395353519751
# 9% GSU Bestseller RMSE: 0.9194760601837428
# 9% GSU Bestseller weighted RMSE: 0.8936775938321354
# **************************************************
#                 10% 실험 시작
# **************************************************
# 10% Bestseller RMSE: 0.9027445786463555
# 10% Bestseller weighted RMSE: 0.8928756400859454
# 10% GSU Bestseller RMSE: 0.9168685485258177
# 10% GSU Bestseller weighted RMSE: 0.8942880370738916
# **************************************************
#                 11% 실험 시작
# **************************************************
# 11% Bestseller RMSE: 0.9040030194716144
# 11% Bestseller weighted RMSE: 0.8933009573519812
# 11% GSU Bestseller RMSE: 0.9174014068046906
# 11% GSU Bestseller weighted RMSE: 0.8947747799586196
# **************************************************
#                 12% 실험 시작
# **************************************************
# 12% Bestseller RMSE: 0.9059975497894884
# 12% Bestseller weighted RMSE: 0.8934184452698102
# 12% GSU Bestseller RMSE: 0.9183957356516554
# 12% GSU Bestseller weighted RMSE: 0.8949062275732702
# **************************************************
#                 13% 실험 시작
# **************************************************
# 13% Bestseller RMSE: 0.9076358413803943
# 13% Bestseller weighted RMSE: 0.8929481349524394
# 13% GSU Bestseller RMSE: 0.9188085314814926
# 13% GSU Bestseller weighted RMSE: 0.8944005846655823
# **************************************************
#                 14% 실험 시작
# **************************************************
# 14% Bestseller RMSE: 0.9082808301041053
# 14% Bestseller weighted RMSE: 0.8931646842521275
# 14% GSU Bestseller RMSE: 0.9188632388407747
# 14% GSU Bestseller weighted RMSE: 0.8946462214752612
# **************************************************
#                 15% 실험 시작
# **************************************************
# 15% Bestseller RMSE: 0.9086469043501758
# 15% Bestseller weighted RMSE: 0.8937168106870295
# 15% GSU Bestseller RMSE: 0.9186251095272032
# 15% GSU Bestseller weighted RMSE: 0.8952135414635836
# **************************************************
#                 16% 실험 시작
# **************************************************
# 16% Bestseller RMSE: 0.9110268977727708
# 16% Bestseller weighted RMSE: 0.8943918005983679
# 16% GSU Bestseller RMSE: 0.9204422597577767
# 16% GSU Bestseller weighted RMSE: 0.8958982585159688
# **************************************************
#                 17% 실험 시작
# **************************************************
# 17% Bestseller RMSE: 0.9125469230620243
# 17% Bestseller weighted RMSE: 0.8947554904996827
# 17% GSU Bestseller RMSE: 0.9213453592801011
# 17% GSU Bestseller weighted RMSE: 0.8962512246567558
# **************************************************
#                 18% 실험 시작
# **************************************************
# 18% Bestseller RMSE: 0.911533063910011
# 18% Bestseller weighted RMSE: 0.8951182299654308
# 18% GSU Bestseller RMSE: 0.9201305911988577
# 18% GSU Bestseller weighted RMSE: 0.8966657848774232
# **************************************************
#                 19% 실험 시작
# **************************************************
# 19% Bestseller RMSE: 0.9110105728872142
# 19% Bestseller weighted RMSE: 0.8954936875880598
# 19% GSU Bestseller RMSE: 0.9187532823392482
# 19% GSU Bestseller weighted RMSE: 0.8969648023839463
# **************************************************
#                 20% 실험 시작
# **************************************************
# 20% Bestseller RMSE: 0.910466966653543
# 20% Bestseller weighted RMSE: 0.8948935433883181
# 20% GSU Bestseller RMSE: 0.9178317167150862
# 20% GSU Bestseller weighted RMSE: 0.8963664934006267
# **************************************************
#                 21% 실험 시작
# **************************************************
# 21% Bestseller RMSE: 0.9091973155054621
# 21% Bestseller weighted RMSE: 0.895401965576919
# 21% GSU Bestseller RMSE: 0.9162651832989517
# 21% GSU Bestseller weighted RMSE: 0.8968862178135517
# **************************************************
#                 22% 실험 시작
# **************************************************
# 22% Bestseller RMSE: 0.9085923051508938
# 22% Bestseller weighted RMSE: 0.8958343778679009
# 22% GSU Bestseller RMSE: 0.9153001303924321
# 22% GSU Bestseller weighted RMSE: 0.8973100994210392
# **************************************************
#                 23% 실험 시작
# **************************************************
# 23% Bestseller RMSE: 0.9075956374020785
# 23% Bestseller weighted RMSE: 0.8967421708004696
# 23% GSU Bestseller RMSE: 0.913952264284855
# 23% GSU Bestseller weighted RMSE: 0.8982041949835081
# **************************************************
#                 24% 실험 시작
# **************************************************
# 24% Bestseller RMSE: 0.9062012543660541
# 24% Bestseller weighted RMSE: 0.8969940674999441
# 24% GSU Bestseller RMSE: 0.9120460381323654
# 24% GSU Bestseller weighted RMSE: 0.8983968156038589
# **************************************************
#                 25% 실험 시작
# **************************************************
# 25% Bestseller RMSE: 0.9067614825391682
# 25% Bestseller weighted RMSE: 0.8972110945603388
# 25% GSU Bestseller RMSE: 0.9122854664986862
# 25% GSU Bestseller weighted RMSE: 0.8985920905502183
# **************************************************
#                 26% 실험 시작
# **************************************************
# 26% Bestseller RMSE: 0.9055267214971042
# 26% Bestseller weighted RMSE: 0.8975853677754508
# 26% GSU Bestseller RMSE: 0.9107696988028287
# 26% GSU Bestseller weighted RMSE: 0.8989485418749392
# **************************************************
#                 27% 실험 시작
# **************************************************
# 27% Bestseller RMSE: 0.9054820298534615
# 27% Bestseller weighted RMSE: 0.8977634269159673
# 27% GSU Bestseller RMSE: 0.910536209148715
# 27% GSU Bestseller weighted RMSE: 0.8991280553256857
# **************************************************
#                 28% 실험 시작
# **************************************************
# 28% Bestseller RMSE: 0.9062924530459501
# 28% Bestseller weighted RMSE: 0.8985372441161158
# 28% GSU Bestseller RMSE: 0.9110592447484814
# 28% GSU Bestseller weighted RMSE: 0.8998719457928246
# **************************************************
#                 29% 실험 시작
# **************************************************
# 29% Bestseller RMSE: 0.9076747480500662
# 29% Bestseller weighted RMSE: 0.8987051453666741
# 29% GSU Bestseller RMSE: 0.9123220703203607
# 29% GSU Bestseller weighted RMSE: 0.9000528688250595
# **************************************************
#                 30% 실험 시작
# **************************************************
# 30% Bestseller RMSE: 0.9082047105746163
# 30% Bestseller weighted RMSE: 0.8992076794515886
# 30% GSU Bestseller RMSE: 0.9128076374309565
# 30% GSU Bestseller weighted RMSE: 0.9005885575084907
# **************************************************
#                 31% 실험 시작
# **************************************************
# 31% Bestseller RMSE: 0.9086137435216046
# 31% Bestseller weighted RMSE: 0.900394889969204
# 31% GSU Bestseller RMSE: 0.9126945178256903
# 31% GSU Bestseller weighted RMSE: 0.9016599300034707
# **************************************************
#                 32% 실험 시작
# **************************************************
# 32% Bestseller RMSE: 0.9092769099076923
# 32% Bestseller weighted RMSE: 0.9000696368397751
# 32% GSU Bestseller RMSE: 0.9134470398131641
# 32% GSU Bestseller weighted RMSE: 0.9014040784095261
# **************************************************
#                 33% 실험 시작
# **************************************************
# 33% Bestseller RMSE: 0.9094395015132886
# 33% Bestseller weighted RMSE: 0.9010176905771158
# 33% GSU Bestseller RMSE: 0.9134662364051617
# 33% GSU Bestseller weighted RMSE: 0.9023465130914339
# **************************************************
#                 34% 실험 시작
# **************************************************
# 34% Bestseller RMSE: 0.9108537634104625
# 34% Bestseller weighted RMSE: 0.9016358788745104
# 34% GSU Bestseller RMSE: 0.9148167772915313
# 34% GSU Bestseller weighted RMSE: 0.9029833035940737
# **************************************************
#                 35% 실험 시작
# **************************************************
# 35% Bestseller RMSE: 0.9124494300430778
# 35% Bestseller weighted RMSE: 0.902007397086652
# 35% GSU Bestseller RMSE: 0.9162605555609401
# 35% GSU Bestseller weighted RMSE: 0.9033412910179037
# **************************************************
#                 36% 실험 시작
# **************************************************
# 36% Bestseller RMSE: 0.9118974179497157
# 36% Bestseller weighted RMSE: 0.9024718371770776
# 36% GSU Bestseller RMSE: 0.9154328855305707
# 36% GSU Bestseller weighted RMSE: 0.9037446055061853
# **************************************************
#                 37% 실험 시작
# **************************************************
# 37% Bestseller RMSE: 0.9105297575844248
# 37% Bestseller weighted RMSE: 0.9024191723090119
# 37% GSU Bestseller RMSE: 0.9139158795282543
# 37% GSU Bestseller weighted RMSE: 0.9036720374282288
# **************************************************
#                 38% 실험 시작
# **************************************************
# 38% Bestseller RMSE: 0.9114504956987867
# 38% Bestseller weighted RMSE: 0.9029688718786049
# 38% GSU Bestseller RMSE: 0.914682700273393
# 38% GSU Bestseller weighted RMSE: 0.9041971096169552
# **************************************************
#                 39% 실험 시작
# **************************************************
# 39% Bestseller RMSE: 0.912117148909053
# 39% Bestseller weighted RMSE: 0.9037754419277539
# 39% GSU Bestseller RMSE: 0.9153366633950379
# 39% GSU Bestseller weighted RMSE: 0.9050310525772881
# **************************************************
#                 40% 실험 시작
# **************************************************
# 40% Bestseller RMSE: 0.9130418138396621
# 40% Bestseller weighted RMSE: 0.9047367823856476
# 40% GSU Bestseller RMSE: 0.9162201028455821
# 40% GSU Bestseller weighted RMSE: 0.9060080979880155
# **************************************************
#                 41% 실험 시작
# **************************************************
# 41% Bestseller RMSE: 0.9147038678119446
# 41% Bestseller weighted RMSE: 0.9043669273858473
# 41% GSU Bestseller RMSE: 0.9181121260635283
# 41% GSU Bestseller weighted RMSE: 0.9057643132689966
# **************************************************
#                 42% 실험 시작
# **************************************************
# 42% Bestseller RMSE: 0.9153181337467345
# 42% Bestseller weighted RMSE: 0.9045044603817534
# 42% GSU Bestseller RMSE: 0.9184810963326442
# 42% GSU Bestseller weighted RMSE: 0.9058329046678355
# **************************************************
#                 43% 실험 시작
# **************************************************
# 43% Bestseller RMSE: 0.9170189076143304
# 43% Bestseller weighted RMSE: 0.9052007064390291
# 43% GSU Bestseller RMSE: 0.9201051146003455
# 43% GSU Bestseller weighted RMSE: 0.9065277754430155
# **************************************************
#                 44% 실험 시작
# **************************************************
# 44% Bestseller RMSE: 0.918979767265293
# 44% Bestseller weighted RMSE: 0.9057603516788593
# 44% GSU Bestseller RMSE: 0.9220183797107857
# 44% GSU Bestseller weighted RMSE: 0.9070973411548762
# **************************************************
#                 45% 실험 시작
# **************************************************
# 45% Bestseller RMSE: 0.9189421237663452
# 45% Bestseller weighted RMSE: 0.9061375085955501
# 45% GSU Bestseller RMSE: 0.9219038406604396
# 45% GSU Bestseller weighted RMSE: 0.9074702811978925
# **************************************************
#                 46% 실험 시작
# **************************************************
# 46% Bestseller RMSE: 0.9198609067525396
# 46% Bestseller weighted RMSE: 0.90730988962951
# 46% GSU Bestseller RMSE: 0.9225004534557156
# 46% GSU Bestseller weighted RMSE: 0.9085240811129709
# **************************************************
#                 47% 실험 시작
# **************************************************
# 47% Bestseller RMSE: 0.9195435092597524
# 47% Bestseller weighted RMSE: 0.907827472996248
# 47% GSU Bestseller RMSE: 0.9219981023927025
# 47% GSU Bestseller weighted RMSE: 0.9089811317687346
# **************************************************
#                 48% 실험 시작
# **************************************************
# 48% Bestseller RMSE: 0.9191274418218867
# 48% Bestseller weighted RMSE: 0.9085210056483004
# 48% GSU Bestseller RMSE: 0.9213584632645327
# 48% GSU Bestseller weighted RMSE: 0.9095918959407705
# **************************************************
#                 49% 실험 시작
# **************************************************
# 49% Bestseller RMSE: 0.9200662181264362
# 49% Bestseller weighted RMSE: 0.9086793083678959
# 49% GSU Bestseller RMSE: 0.9221626843458474
# 49% GSU Bestseller weighted RMSE: 0.9097065768154073
# **************************************************
#                 50% 실험 시작
# **************************************************
# 50% Bestseller RMSE: 0.9200564013040811
# 50% Bestseller weighted RMSE: 0.9092682299317523
# 50% GSU Bestseller RMSE: 0.9221663734688954
# 50% GSU Bestseller weighted RMSE: 0.9103232160141594

# %%
with open('/home/ryu/thesis/real_movielens/additional_var/Bestseller/84p_Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(bias_bestseller, f)
with open('/home/ryu/thesis/real_movielens/additional_var/Bestseller/84p_Weighted Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(weighted_bias_bs, f)
with open('/home/ryu/thesis/real_movielens/additional_var/Bestseller/84p_Gray Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(gray_bias_bestseller, f)
with open('/home/ryu/thesis/real_movielens/additional_var/Bestseller/84p_Weighted Gray Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(weighted_gray_bias_bs, f)
