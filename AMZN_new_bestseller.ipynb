# %%
# 필요한 모듈 불러오기

import os
import numpy as np
import pandas as pd

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action = 'ignore')

import pickle

# %%
# 실험 준비

## 데이터 불러오기
ratings = pd.read_csv('/home/ryu/thesis/data/amazon/Amazon_ratings.csv')

## 기본 전처리
cnt = ratings.groupby('user_id').count()['rating']
keys = cnt[cnt>3].keys()
ratings = ratings[ratings['user_id'].isin(keys)]

## train, test set 나누기
x = ratings.copy()
y = ratings['user_id']
ratings_train, ratings_test = train_test_split(x, test_size=0.25, stratify=y, random_state=8)

## Black Sheep 사용자 목록 불러오기
with open('/home/ryu/thesis/real_amazon/black_id.pkl', 'rb') as f:
    black = pickle.load(f)

## train, test 에서 black sheep 사용자만 추출
black_train = ratings_train[ratings_train['user_id'].isin(black)]
black_test = ratings_test[ratings_test['user_id'].isin(black)]
black_all = ratings[ratings['user_id'].isin(black)]

## 사용자 수 구하기 (이후 가중평균 위함)
entire_pop = ratings.user_id.nunique()      # 전체 사용자 수
black_pop = len(black)                      # Black Sheep 사용자 수
rest_pop = entire_pop - black_pop           # 전체 - black sheep = white & gray 사용자 수

## black sheep 제거 데이터
ratings_train = ratings_train[~ratings_train['user_id'].isin(black)]
ratings_test = ratings_test[~ratings_test['user_id'].isin(black)]
ratings = ratings[~ratings['user_id'].isin(black)]


# White Sheep 대상 MF 실험 결과 불러오기 (NeuMF 실험 시 사용)
with open('/home/ryu/thesis/real_amazon/additional_var/White_FM/84c_White FM.pkl', 'rb') as f:
    white_results_loaded = pickle.load(f)

## Open saved user_gsu_dict (Gray Sheep id 불러오기)
with open('/home/ryu/thesis/real_amazon/additional_var/1_gsu_data/FM_84_cosine_gsu.pkl', 'rb') as f:
    gray_dict = pickle.load(f)

# %%
# RMSE 준비
def RMSE(y_true, y_pred):
    return np.sqrt(np.mean((np.array(y_true) - np.array(y_pred))**2))


# 모델 준비
## 1. Bestseller
def Bestseller(train_data, test_data):

    train = train_data.copy()
    test = test_data.copy()

    per_item_mean = train.groupby(['item_id'])['rating'].mean()
    global_mean = train['rating'].mean()

    test = test.join(per_item_mean, on='item_id', rsuffix='_mean')
    test['rating_mean'].fillna(global_mean, inplace=True)

    rmse_result = RMSE(test['rating'], test['rating_mean'])
    
    return rmse_result

def Biased_Bestseller(train_data, test_data):

    train = train_data.copy()
    test = test_data.copy()

    # 아이템별 평균 평점 계산
    rating_mean = train.groupby('item_id')['rating'].mean()
    test = test.join(rating_mean, on='item_id', rsuffix='_item')

    # 전체 평균 평점 계산
    global_mean = train['rating'].mean()
    test['rating_item'].fillna(train['rating'].mean(), inplace=True)

    # 사용자별 평균 평점
    user_mean = train.groupby('user_id')['rating'].mean()
    test = test.join(user_mean, on='user_id', rsuffix='_user')
    
    
    test['predicted_rating'] = test['rating_item'] - global_mean + test['rating_user']

    rmse_result = RMSE(test['rating'], test['predicted_rating'])

    return rmse_result

# %%
bias_bestseller = {}
# weighted_bias_bs = {}
gray_bias_bestseller = {}
# weighted_gray_bias_bs = {}
# black_bestseller = {}
weighted_bs_black_w = {}
weighted_bs_black_blk = {}
weighted_graybs_black_w = {}
weighted_graybs_black_blk = {}


print('*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*')
blk_only_bs = Bestseller(black_train, black_test)
print(f'Black Bestseller (trained with only black sheep data): {blk_only_bs}')
print('*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*')

for thresh in gray_dict.keys():

    
    gray_idx = gray_dict[thresh]    # thresh%에 해당하는 Gray sheep 사용자 id 가져오기
    white_rmse = white_results_loaded[thresh]    # thresh%에 해당하는 White Sheep MF 결과 가져오기 (NeuMF 실험 시에만 사용!)

    print('**************************************************')
    print(f'                {thresh}% 실험 시작                ')
    print('**************************************************')


    # white, gray sheep 사용자 분리
    white = ratings[~ratings['user_id'].isin(gray_idx)]
    gray = ratings[ratings['user_id'].isin(gray_idx)]

    white_train = ratings_train[~ratings_train['user_id'].isin(gray_idx)]
    white_test = ratings_test[~ratings_test['user_id'].isin(gray_idx)]

    gray_train = ratings_train[ratings_train['user_id'].isin(gray_idx)]
    gray_test = ratings_test[ratings_test['user_id'].isin(gray_idx)]


    #### 0. Black Sheep Bestseller (trained with White Sheep train set)
    blk_bestseller = Bestseller(white_train, black_test)

    print(f'{thresh}% Black Bestseller RMSE (trained with white_train): {blk_bestseller}')


    #### 2. Bestseller with all ratings ####
    bias_bestseller_rmse = Biased_Bestseller(ratings_train, gray_test)
    
    print(f'{thresh}% Bestseller RMSE: {bias_bestseller_rmse}')
    bias_bestseller[f'{thresh}'] = bias_bestseller_rmse

    # white sheep trained, black sheep tested
    weight_avg_bs = (blk_bestseller * (black_pop/entire_pop)) + (white_rmse * ((rest_pop-len(gray_idx))/entire_pop)) + (bias_bestseller_rmse * (len(gray_idx)/entire_pop))
    print(f'{thresh}% Bestseller weighted RMSE (w/ White Sheep): {weight_avg_bs}')
    weighted_bs_black_w[f'{thresh}'] = weight_avg_bs

    # black sheep trained, black sheep tested
    blk_weight_avg_bs = (blk_only_bs * (black_pop/entire_pop)) + (white_rmse * ((rest_pop-len(gray_idx))/entire_pop)) + (bias_bestseller_rmse * (len(gray_idx)/entire_pop))
    print(f'{thresh}% Bestseller weighted RMSE (w/ Black Sheep): {blk_weight_avg_bs}')
    weighted_bs_black_blk[f'{thresh}'] = blk_weight_avg_bs


    #### 3. Gray Sheep Only Bestseller ####
    gsu_bias_bestseller_rmse = Biased_Bestseller(gray_train, gray_test)

    print(f'{thresh}% GSU Bestseller RMSE: {gsu_bias_bestseller_rmse}')
    gray_bias_bestseller[f'{thresh}'] = gsu_bias_bestseller_rmse

    # white sheep trained, black sheep tested
    weight_avg_bs = (blk_bestseller * (black_pop/entire_pop)) + (white_rmse * ((rest_pop-len(gray_idx))/entire_pop)) + (gsu_bias_bestseller_rmse * (len(gray_idx)/entire_pop))
    print(f'{thresh}% Bestseller weighted RMSE (w/ White Sheep): {weight_avg_bs}')
    weighted_graybs_black_w[f'{thresh}'] = weight_avg_bs

    # black sheep trained, black sheep tested
    blk_weight_avg_bs = (blk_only_bs * (black_pop/entire_pop)) + (white_rmse * ((rest_pop-len(gray_idx))/entire_pop)) + (gsu_bias_bestseller_rmse * (len(gray_idx)/entire_pop))
    print(f'{thresh}% Bestseller weighted RMSE (w/ Black Sheep): {blk_weight_avg_bs}')
    weighted_graybs_black_blk[f'{thresh}'] = blk_weight_avg_bs
# Out:
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 17% Bestseller weighted RMSE (w/ White Sheep): 1.0503232549599943
# 17% Bestseller weighted RMSE (w/ Black Sheep): 1.107225006473999
# **************************************************
#                 18% 실험 시작
# **************************************************
# 18% Black Bestseller RMSE (trained with white_train): 1.1608798639417035
# 18% Bestseller RMSE: 1.038877335085409
# 18% Bestseller weighted RMSE (w/ White Sheep): 1.0393204318949092
# 18% Bestseller weighted RMSE (w/ Black Sheep): 1.0957520588066787
# 18% GSU Bestseller RMSE: 1.1675793202229763
# 18% Bestseller weighted RMSE (w/ White Sheep): 1.052179506641584
# 18% Bestseller weighted RMSE (w/ Black Sheep): 1.1086111335533535
# **************************************************
#                 19% 실험 시작
# **************************************************
# 19% Black Bestseller RMSE (trained with white_train): 1.1617739561078322
# 19% Bestseller RMSE: 1.0438516138635374
# 19% Bestseller weighted RMSE (w/ White Sheep): 1.0408029373625824
# 19% Bestseller weighted RMSE (w/ Black Sheep): 1.0968366404546355
# 19% GSU Bestseller RMSE: 1.1701531828089564
# 19% Bestseller weighted RMSE (w/ White Sheep): 1.0541208210370345
# 19% Bestseller weighted RMSE (w/ Black Sheep): 1.1101545241290875
# **************************************************
#                 20% 실험 시작
# **************************************************
# 20% Black Bestseller RMSE (trained with white_train): 1.1627450218429483
# 20% Bestseller RMSE: 1.0415139544089382
# 20% Bestseller weighted RMSE (w/ White Sheep): 1.0415348961520992
# 20% Bestseller weighted RMSE (w/ Black Sheep): 1.097136417640117
# 20% GSU Bestseller RMSE: 1.165725363900478
# 20% Bestseller weighted RMSE (w/ White Sheep): 1.0553266210780685
# 20% Bestseller weighted RMSE (w/ Black Sheep): 1.1109281425660862
# **************************************************
#                 21% 실험 시작
# **************************************************
# 21% Black Bestseller RMSE (trained with white_train): 1.1627314473270984
# 21% Bestseller RMSE: 1.0427141726119376
# 21% Bestseller weighted RMSE (w/ White Sheep): 1.0424709177737226
# 21% Bestseller weighted RMSE (w/ Black Sheep): 1.098078480723015
# 21% GSU Bestseller RMSE: 1.1704315158022347
# 21% Bestseller weighted RMSE (w/ White Sheep): 1.0573583960378523
# 21% Bestseller weighted RMSE (w/ Black Sheep): 1.1129659589871448
# **************************************************
#                 22% 실험 시작
# **************************************************
# 22% Black Bestseller RMSE (trained with white_train): 1.1635622927759637
# 22% Bestseller RMSE: 1.0470753505412143
# 22% Bestseller weighted RMSE (w/ White Sheep): 1.043649953202702
# 22% Bestseller weighted RMSE (w/ Black Sheep): 1.0988877408568611
# 22% GSU Bestseller RMSE: 1.1754224895100165
# 22% Bestseller weighted RMSE (w/ White Sheep): 1.0593208023801661
# 22% Bestseller weighted RMSE (w/ Black Sheep): 1.1145585900343256
# **************************************************
#                 23% 실험 시작
# **************************************************
# 23% Black Bestseller RMSE (trained with white_train): 1.16350857211235
# 23% Bestseller RMSE: 1.050142280423832
# 23% Bestseller weighted RMSE (w/ White Sheep): 1.0446412301002868
# 23% Bestseller weighted RMSE (w/ Black Sheep): 1.0999029266225389
# 23% GSU Bestseller RMSE: 1.1768474727871803
# 23% Bestseller weighted RMSE (w/ White Sheep): 1.0608197784308646
# 23% Bestseller weighted RMSE (w/ Black Sheep): 1.1160814749531167
# **************************************************
#                 24% 실험 시작
# **************************************************
# 24% Black Bestseller RMSE (trained with white_train): 1.1643714598090236
# 24% Bestseller RMSE: 1.0521471185267564
# 24% Bestseller weighted RMSE (w/ White Sheep): 1.045559531733288
# 24% Bestseller weighted RMSE (w/ Black Sheep): 1.1004371922676919
# 24% GSU Bestseller RMSE: 1.1819952189495824
# 24% Bestseller weighted RMSE (w/ White Sheep): 1.0628576480212497
# 24% Bestseller weighted RMSE (w/ Black Sheep): 1.1177353085556536
# **************************************************
#                 25% 실험 시작
# **************************************************
# 25% Black Bestseller RMSE (trained with white_train): 1.1650191282486844
# 25% Bestseller RMSE: 1.056332278803261
# 25% Bestseller weighted RMSE (w/ White Sheep): 1.0469362412452519
# 25% Bestseller weighted RMSE (w/ Black Sheep): 1.1015256510721976
# 25% GSU Bestseller RMSE: 1.1863909958390741
# 25% Bestseller weighted RMSE (w/ White Sheep): 1.0649818413963459
# 25% Bestseller weighted RMSE (w/ Black Sheep): 1.1195712512232916
# **************************************************
#                 26% 실험 시작
# **************************************************
# 26% Black Bestseller RMSE (trained with white_train): 1.1658698653153379
# 26% Bestseller RMSE: 1.0566151004038322
# 26% Bestseller weighted RMSE (w/ White Sheep): 1.048417946416346
# 26% Bestseller weighted RMSE (w/ Black Sheep): 1.102628728003428
# 26% GSU Bestseller RMSE: 1.1836413787501463
# 26% Bestseller weighted RMSE (w/ White Sheep): 1.0667527679235493
# 26% Bestseller weighted RMSE (w/ Black Sheep): 1.1209635495106314
# **************************************************
#                 27% 실험 시작
# **************************************************
# 27% Black Bestseller RMSE (trained with white_train): 1.1672086654952871
# 27% Bestseller RMSE: 1.0581495322440055
# 27% Bestseller weighted RMSE (w/ White Sheep): 1.0502788414536135
# 27% Bestseller weighted RMSE (w/ Black Sheep): 1.1038937778900226
# 27% GSU Bestseller RMSE: 1.1823454598213965
# 27% Bestseller weighted RMSE (w/ White Sheep): 1.0688921291302942
# 27% Bestseller weighted RMSE (w/ Black Sheep): 1.1225070655667033
# **************************************************
#                 28% 실험 시작
# **************************************************
# 28% Black Bestseller RMSE (trained with white_train): 1.1710474388532481
# 28% Bestseller RMSE: 1.0600253065294165
# 28% Bestseller weighted RMSE (w/ White Sheep): 1.053087328360035
# 28% Bestseller weighted RMSE (w/ Black Sheep): 1.1049937839311668
# 28% GSU Bestseller RMSE: 1.1863670242811961
# 28% Bestseller weighted RMSE (w/ White Sheep): 1.0727210715335613
# 28% Bestseller weighted RMSE (w/ Black Sheep): 1.124627527104693
# **************************************************
#                 29% 실험 시작
# **************************************************
# 29% Black Bestseller RMSE (trained with white_train): 1.1727180582651195
# 29% Bestseller RMSE: 1.0592605769314776
# 29% Bestseller weighted RMSE (w/ White Sheep): 1.0546326550703564
# 29% Bestseller weighted RMSE (w/ Black Sheep): 1.105795586335104
# 29% GSU Bestseller RMSE: 1.1853262775354558
# 29% Bestseller weighted RMSE (w/ White Sheep): 1.074920843015439
# 29% Bestseller weighted RMSE (w/ Black Sheep): 1.1260837742801868
# **************************************************
#                 30% 실험 시작
# **************************************************
# 30% Black Bestseller RMSE (trained with white_train): 1.173021893957834
# 30% Bestseller RMSE: 1.0616520550618467
# 30% Bestseller weighted RMSE (w/ White Sheep): 1.055936859673378
# 30% Bestseller weighted RMSE (w/ Black Sheep): 1.1069645661100918
# 30% GSU Bestseller RMSE: 1.1881992642104215
# 30% Bestseller weighted RMSE (w/ White Sheep): 1.0770098319833397
# 30% Bestseller weighted RMSE (w/ Black Sheep): 1.1280375384200534
# **************************************************
#                 31% 실험 시작
# **************************************************
# 31% Black Bestseller RMSE (trained with white_train): 1.1740901036168834
# 31% Bestseller RMSE: 1.0631509023658618
# 31% Bestseller weighted RMSE (w/ White Sheep): 1.057756093471851
# 31% Bestseller weighted RMSE (w/ Black Sheep): 1.1083083835209824
# 31% GSU Bestseller RMSE: 1.187076300938371
# 31% Bestseller weighted RMSE (w/ White Sheep): 1.07907797420579
# 31% Bestseller weighted RMSE (w/ Black Sheep): 1.1296302642549214
# **************************************************
#                 32% 실험 시작
# **************************************************
# 32% Black Bestseller RMSE (trained with white_train): 1.175315010757921
# 32% Bestseller RMSE: 1.0639049971423042
# 32% Bestseller weighted RMSE (w/ White Sheep): 1.0595206006289426
# 32% Bestseller weighted RMSE (w/ Black Sheep): 1.1095277346563293
# 32% GSU Bestseller RMSE: 1.1837521140147869
# 32% Bestseller weighted RMSE (w/ White Sheep): 1.080803735990567
# 32% Bestseller weighted RMSE (w/ Black Sheep): 1.1308108700179536
# **************************************************
#                 33% 실험 시작
# **************************************************
# 33% Black Bestseller RMSE (trained with white_train): 1.175698138996654
# 33% Bestseller RMSE: 1.0603471065962986
# 33% Bestseller weighted RMSE (w/ White Sheep): 1.0603756180540926
# 33% Bestseller weighted RMSE (w/ Black Sheep): 1.1102122373873868
# 33% GSU Bestseller RMSE: 1.1767906399039896
# 33% Bestseller weighted RMSE (w/ White Sheep): 1.0817051480100217
# 33% Bestseller weighted RMSE (w/ Black Sheep): 1.131541767343316
# **************************************************
#                 34% 실험 시작
# **************************************************
# 34% Black Bestseller RMSE (trained with white_train): 1.1771271131670973
# 34% Bestseller RMSE: 1.061838008487055
# 34% Bestseller weighted RMSE (w/ White Sheep): 1.0620128477795026
# 34% Bestseller weighted RMSE (w/ Black Sheep): 1.111213489210607
# 34% GSU Bestseller RMSE: 1.1729845186606735
# 34% Bestseller weighted RMSE (w/ White Sheep): 1.082986908327967
# 34% Bestseller weighted RMSE (w/ Black Sheep): 1.1321875497590714
# **************************************************
#                 35% 실험 시작
# **************************************************
# 35% Black Bestseller RMSE (trained with white_train): 1.1777508932761285
#                 41% 실험 시작
# **************************************************
# 41% Black Bestseller RMSE (trained with white_train): 1.1888800236101758
# 41% Bestseller RMSE: 1.0577115045739642
# 41% Bestseller weighted RMSE (w/ White Sheep): 1.0740265693140465
# 41% Bestseller weighted RMSE (w/ Black Sheep): 1.1179964714618127
# 41% GSU Bestseller RMSE: 1.1454665822497903
# 41% Bestseller weighted RMSE (w/ White Sheep): 1.093994578633657
# 41% Bestseller weighted RMSE (w/ Black Sheep): 1.1379644807814229
# **************************************************
#                 42% 실험 시작
# **************************************************
# 42% Black Bestseller RMSE (trained with white_train): 1.1917842373934833
# 42% Bestseller RMSE: 1.0594621964960425
# 42% Bestseller weighted RMSE (w/ White Sheep): 1.0766128918805153
# 42% Bestseller weighted RMSE (w/ Black Sheep): 1.119290247369551
# 42% GSU Bestseller RMSE: 1.1433904955583576
# 42% Bestseller weighted RMSE (w/ White Sheep): 1.0961792357587135
# 42% Bestseller weighted RMSE (w/ Black Sheep): 1.138856591247749
# **************************************************
#                 43% 실험 시작
# **************************************************
# 43% Black Bestseller RMSE (trained with white_train): 1.19272293213283
# 43% Bestseller RMSE: 1.0613294354954215
# 43% Bestseller weighted RMSE (w/ White Sheep): 1.0781320833558992
# 43% Bestseller weighted RMSE (w/ Black Sheep): 1.120391664245873
# 43% GSU Bestseller RMSE: 1.145038667539316
# 43% Bestseller weighted RMSE (w/ White Sheep): 1.0981103973360669
# 43% Bestseller weighted RMSE (w/ Black Sheep): 1.1403699782260408
# **************************************************
#                 44% 실험 시작
# **************************************************
# 44% Black Bestseller RMSE (trained with white_train): 1.1952366621752817
# 44% Bestseller RMSE: 1.0600853532048442
# 44% Bestseller weighted RMSE (w/ White Sheep): 1.0801164473580749
# 44% Bestseller weighted RMSE (w/ Black Sheep): 1.1212572699162773
# 44% GSU Bestseller RMSE: 1.141738773524017
# 44% Bestseller weighted RMSE (w/ White Sheep): 1.1000557844547418
# 44% Bestseller weighted RMSE (w/ Black Sheep): 1.1411966070129442
# **************************************************
#                 45% 실험 시작
# **************************************************
# 45% Black Bestseller RMSE (trained with white_train): 1.1971640118812976
# 45% Bestseller RMSE: 1.0563011872780603
# 45% Bestseller weighted RMSE (w/ White Sheep): 1.0814522082593967
# 45% Bestseller weighted RMSE (w/ Black Sheep): 1.121735246367627
# 45% GSU Bestseller RMSE: 1.135546872556243
# 45% Bestseller weighted RMSE (w/ White Sheep): 1.1012419403248328
# 45% Bestseller weighted RMSE (w/ Black Sheep): 1.141524978433063
# **************************************************
#                 46% 실험 시작
# **************************************************
# 46% Black Bestseller RMSE (trained with white_train): 1.200676141210793
# 46% Bestseller RMSE: 1.0573265308583661
# 46% Bestseller weighted RMSE (w/ White Sheep): 1.0835875670606028
# 46% Bestseller weighted RMSE (w/ Black Sheep): 1.122307500188077
# 46% GSU Bestseller RMSE: 1.133810727903077
# 46% Bestseller weighted RMSE (w/ White Sheep): 1.1031151658566336
# 46% Bestseller weighted RMSE (w/ Black Sheep): 1.1418350989841077
# **************************************************
#                 47% 실험 시작
# **************************************************
# 47% Black Bestseller RMSE (trained with white_train): 1.2029353283300648
# 47% Bestseller RMSE: 1.0545137346520543
# 47% Bestseller weighted RMSE (w/ White Sheep): 1.0849732531365126
# 47% Bestseller weighted RMSE (w/ Black Sheep): 1.1226877145665362
# 47% GSU Bestseller RMSE: 1.1299298269979972
# 47% Bestseller weighted RMSE (w/ White Sheep): 1.104645315945506
# 47% Bestseller weighted RMSE (w/ Black Sheep): 1.1423597773755296
# **************************************************
#                 48% 실험 시작
# **************************************************
# 48% Black Bestseller RMSE (trained with white_train): 1.2043712955247892
# 48% Bestseller RMSE: 1.0526864377278728
# 48% Bestseller weighted RMSE (w/ White Sheep): 1.0859883792871647
# 48% Bestseller weighted RMSE (w/ Black Sheep): 1.1230637505061798
# 48% GSU Bestseller RMSE: 1.1256236840535678
# 48% Bestseller weighted RMSE (w/ White Sheep): 1.1054172983170516
# 48% Bestseller weighted RMSE (w/ Black Sheep): 1.1424926695360667
# **************************************************
#                 49% 실험 시작
# **************************************************
# 49% Black Bestseller RMSE (trained with white_train): 1.2089319568657984
# 49% Bestseller RMSE: 1.054432412924638
# 49% Bestseller weighted RMSE (w/ White Sheep): 1.0894123729763738
# 49% Bestseller weighted RMSE (w/ Black Sheep): 1.1244579805423809
# 49% GSU Bestseller RMSE: 1.1264672851982924
# 49% Bestseller weighted RMSE (w/ White Sheep): 1.109003533859788
# 49% Bestseller weighted RMSE (w/ Black Sheep): 1.144049141425795
# **************************************************
#                 50% 실험 시작
# **************************************************
# 50% Black Bestseller RMSE (trained with white_train): 1.2127509652748145
# 50% Bestseller RMSE: 1.0534761315060397
# 50% Bestseller weighted RMSE (w/ White Sheep): 1.0913805104468521
# 50% Bestseller weighted RMSE (w/ Black Sheep): 1.1247264337171956
# 50% GSU Bestseller RMSE: 1.1239797089759305
# 50% Bestseller weighted RMSE (w/ White Sheep): 1.1109452024142963
# 50% Bestseller weighted RMSE (w/ Black Sheep): 1.1442911256846398

# %%
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(bias_bestseller, f)
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Gray Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(gray_bias_bestseller, f)

# weighted rmse: black with black only
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Weighted Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(weighted_bs_black_blk, f)
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Weighted Biased Bestseller_Black.pkl', 'wb') as f:
    pickle.dump(weighted_graybs_black_blk, f)
    
# weighted rmse: black with white
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Weighted Gray Biased Bestseller.pkl', 'wb') as f:
    pickle.dump(weighted_bs_black_w, f)
with open('/home/ryu/thesis/real_amazon/additional_var/Biased Bestseller/84p_Weighted Gray Biased Bestseller_Black.pkl', 'wb') as f:
    pickle.dump(weighted_graybs_black_blk, f)
